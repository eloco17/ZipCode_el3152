# %%
import pandas as pd
import numpy as np
datafile = "/Users/Eric/Downloads/311_Service_Requests_2020.csv"
df = pd.read_csv(datafile)
df2= df[df['Incident Zip']==10033]
#df2.groupby(['Descriptor'])
df2
# Out:
# C:\Users\Eric\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (20,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          Unique Key            Created Date             Closed Date Agency  \
# 63         45281372  01/01/2020 12:17:03 AM  01/01/2020 01:49:50 AM   NYPD
# 230        45283111  01/01/2020 12:53:44 AM  01/01/2020 02:31:42 AM   NYPD
# 356        45283275  01/01/2020 01:19:41 AM  01/01/2020 02:12:15 AM   NYPD
# 377        45279884  01/01/2020 01:23:05 AM  01/01/2020 02:05:44 AM   NYPD
# 479        45278839  01/01/2020 01:39:35 AM  01/01/2020 02:26:29 AM   NYPD
# ...             ...                     ...                     ...    ...
# 2586752    48532774  12/30/2020 10:04:15 PM  12/30/2020 10:17:44 PM   NYPD
# 2586765    48530641  12/30/2020 10:06:35 PM  12/30/2020 10:18:17 PM   NYPD
# ...

# %%
descriptor_count=df2.groupby(['Descriptor']).size().reset_index().sort_values(by=0, ascending = False)
top10= descriptor_count.head(10).rename(columns={0:'count'})
top10=top10.iloc[0,:]
top10
# Out:
# Descriptor    Loud Music/Party
# count                     6642
# Name: 198, dtype: object

# %%
descriptor_count=df2.groupby(['Descriptor']).size().nlargest(10)
descriptor_count
# Out:
# Descriptor
# Loud Music/Party              6642
# ENTIRE BUILDING               2860
# Car/Truck Music               1426
# Banging/Pounding               649
# Social Distancing              628
# Loud Talking                   605
# APARTMENT ONLY                 599
# PESTS                          398
# Business not in compliance     302
# FLOOR                          276
# dtype: int64

# %%
descriptor_count=df2.groupby(['Descriptor']).size().reset_index()
total_10033=descriptor_count.loc[descriptor_count['Descriptor'].str.contains("parking",case=False)].rename(columns={0:'count'})
total_parking_10033=total_10033['count'].sum()

# %%
descriptor_count=df2.groupby(['Descriptor']).size().reset_index().rename(columns={0:'count'})
total_incidents_10033=descriptor_count['count'].sum()
total_incidents_10033
# Out:
# 22046

# %%
descriptor_count=df.groupby(['Descriptor']).size().reset_index()
total=descriptor_count.loc[descriptor_count['Descriptor'].str.contains("parking",case=False)].rename(columns={0:'count'})
total_number_parking=total['count'].sum()

# %%
descriptor_count=df.groupby(['Descriptor']).size().reset_index().rename(columns={0:'count'})
total_incidents=descriptor_count['count'].sum()
total_incidents
# Out:
# 2489304

# %%
higher_parking_proportion = (total_parking_10033/total_incidents_10033)>(total_number_parking/total_incidents)
higher_parking_proportion
# Out:
# False
